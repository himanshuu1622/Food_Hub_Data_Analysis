# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # INDEX

# %% [markdown]
# 1. List of Tables
# 2. List of Figures
# 3. Problem Statement Objective
# 4. Importing The Necessary Libraries
# 5. Basic Exploration
# 6. Data Wrangling
# 7. Data Preprocessing
# 8. Feature Enginnering
# 9. Data visualization
# 10. Order Analysis
# 11. Customer Behavior
# 12. Restaurant Performance
# 13. Demand Patterns
# 14. Operational Efficiency
# 15. Customer Insights

# %% [markdown]
# # List Of Tables
# 1. Data Head
# 2. Data Tail
# 3. Data Types
# 4. Data Summary Statistics
# 5. NUll values
# 6. Wrong Entries(Delivery time)
# 7. the average food preparation time for each restaurant
# 8. the average delivery time compare across different restaurants
# 9. Correlation between the cost of the order and the rating given

# %% [markdown]
# # List of Figures
# 1. Check Outliers
# 2. Check Outliers (After Handling Missing Values)
# 3. The Total Number Of orders
# 4. Countplot Between rating  and the day of the week
# 5. coutplot of day of the week
# 6. Heatmap between the cost of order and the rating
# 7. countplot between the cuisine type and the day of the week
# 8. piechart of rating 4 and higher

# %% [markdown]
# # Problem Statement Objective
#
# **The food aggregator company has stored the data of the different orders made by the registered customers in their online portal. They want to analyze the data to get a fair idea about the demand of different restaurants which will help them in enhancing their customer experience. Suppose you are hired as a Data Scientist in this company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.**

# %% [markdown]
# # Importing The Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading The Dataset**

# %%
df=pd.read_csv(r"D:\bootcamp ml\files\data\2-foodhub_order_New.csv")

# %% [markdown]
# # Basic Exploration

# %% [markdown]
# **Data Head(Top 5 rows)**

# %%
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                   25.0
# 1              12.08         Weekend  Not given                   25.0
# 2              12.23         Weekday          5                   23.0
# 3              29.20         Weekend          3                   25.0
# 4              11.59         Weekday          4                   25.0
#
#   delivery_time
# 0            20
# 1             ?
# 2            28
# 3            15
# 4            24

# %% [markdown]
# **Data Tail(last 5 Rows)**

# %%
df.tail()
# Out:
#       order_id  customer_id                        restaurant_name  \
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 1893        Mexican              22.31         Weekend          5
# 1894       American              12.18         Weekend          5
# 1895       Japanese              25.22         Weekday  Not given
# 1896  Mediterranean              12.18         Weekday          5
# 1897       Japanese              19.45         Weekend  Not given
#
#       food_preparation_time delivery_time
# 1893                   31.0            17
# 1894                   31.0            19
# 1895                   31.0            24
# 1896                   23.0            31
# 1897                   28.0            24

# %% [markdown]
# # Observation
# **In Delivery_time '?' is there need to check in future**
#
# **In Rating , In some of the data rating is "Not given"**

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# **Shape of Data**

# %%
df.shape
# Out:
# (1898, 9)

# %% [markdown]
# **Number of Rows are 1898 and Number of columns are 9**

# %% [markdown]
# # Data Types of Each Feature

# %%
df.dtypes
# Out:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time    float64
# delivery_time             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1895 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1896 non-null   float64
#  8   delivery_time          1898 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 133.6+ KB

# %% [markdown]
# # Observation

# %% [markdown]
# **delivery time is apearing as "object" but it should be in "int"**
#
# **rating is apeaaring as "obejct" but it should be in "int"**

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time
# count  1.898000e+03    1898.000000        1898.000000            1896.000000
# mean   1.477496e+06  171168.478398          80.722007              27.371835
# std    5.480497e+02  113698.139743        2798.141333               4.634211
# min    1.476547e+06    1311.000000           0.000000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.160000              27.000000
# 75%    1.477970e+06  270525.000000          22.310000              31.000000
# max    1.478444e+06  405334.000000      121920.000000              35.000000

# %% [markdown]
# # Observation

# %% [markdown]
# **cost of the order is 0.00 at minimum**

# %% [markdown]
# # The Null Values

# %% [markdown]
# **Check For Missing Values in Columns**

# %%
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             3
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    2
# delivery_time            0
# dtype: int64

# %% [markdown]
# # Observation

# %% [markdown]
# **3 NULL value are in Cuisine type and 2 NULL values are in Food delivery Time**

# %% [markdown]
# **To fetch all the rows having atleast one NULL value**

# %%
df[df.isnull().sum(axis=1)>0]
# Out:
#      order_id  customer_id            restaurant_name cuisine_type  \
# 11    1478437       221206     Empanada Mama (closed)          NaN
# 51    1477883        91817  Blue Ribbon Fried Chicken          NaN
# 95    1477027       164016  Blue Ribbon Fried Chicken          NaN
# 140   1477376       370372  Blue Ribbon Fried Chicken     American
# 188   1477872       300670                Shake Shack     American
#
#      cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 11                8.10         Weekend          5                   23.0
# 51               29.39         Weekend  Not given                   27.0
# 95               16.39         Weekend  Not given                   27.0
# 140              11.59         Weekday  Not given                    NaN
# 188              13.39         Weekend  Not given                    NaN
#
#     delivery_time
# 11             22
# 51             28
# 95             22
# 140            24
# 188            22

# %% [markdown]
# **Check for percentage wise missing values in columns**

# %%
df.isnull().sum()/len(df)*100
# Out:
# order_id                 0.000000
# customer_id              0.000000
# restaurant_name          0.000000
# cuisine_type             0.158061
# cost_of_the_order        0.000000
# day_of_the_week          0.000000
# rating                   0.000000
# food_preparation_time    0.105374
# delivery_time            0.000000
# dtype: float64

# %% [markdown]
# # The Duplicate values

# %% [markdown]
# **Check for the duplicate values**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **As there are zero duplicate values**

# %% [markdown]
# # The Anomalies or Wrong Entries

# %% [markdown]
# **From above Obvervation we found wrong entry in delivery time**

# %% [markdown]
# **Check for all unique values in delivery time**

# %%
df['delivery_time'].unique()
# Out:
# array(['20', '?', '28', '15', '24', '21', '30', '26', '22', '17', '23',
#        '25', '16', '29', '27', '18', '31', '32', '19', '33'], dtype=object)

# %% [markdown]
# **Shows the columns which have entry '?' in delivery Time**

# %%
df[df['delivery_time']=='?']
# Out:
#      order_id  customer_id            restaurant_name cuisine_type  \
# 1     1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 180   1476808        84700                Pepe Giallo      Italian
#
#      cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 1                12.08         Weekend  Not given                   25.0
# 180              14.60         Weekday          3                   32.0
#
#     delivery_time
# 1               ?
# 180             ?

# %% [markdown]
# **Replacing all '?' with the NULL**

# %%
df['delivery_time']=df['delivery_time'].replace('?',np.nan)

# %%
df['delivery_time'].unique()
# Out:
# array(['20', nan, '28', '15', '24', '21', '30', '26', '22', '17', '23',
#        '25', '16', '29', '27', '18', '31', '32', '19', '33'], dtype=object)

# %% [markdown]
# **Now there is not any wrong entry in the "Delivery time"**

# %% [markdown]
# **From The Above Observattion "Not given" is mention in the "Rating"**

# %% [markdown]
# **Check for all unique values**

# %%
df['rating'].unique()
# Out:
# array(['Not given', '5', '3', '4'], dtype=object)

# %% [markdown]
# **Shows the columns which have entry 'Not given' in rating**

# %%
df[df['rating']=="Not given"]
# Out:
#       order_id  customer_id             restaurant_name cuisine_type  \
# 0      1477147       337525                     Hangawi       Korean
# 1      1477685       358141   Blue Ribbon Sushi Izakaya     Japanese
# 6      1477894       157711           The Meatball Shop      Italian
# 10     1477895       143926  Big Wong Restaurant _¤¾Ñ¼      Chinese
# 14     1478198        62667      Lucky's Famous Burgers     American
# ...        ...          ...                         ...          ...
# 1887   1476873       237616                 Shake Shack     American
# 1891   1476981       138586                 Shake Shack     American
# 1892   1477473        97838                 Han Dynasty      Chinese
# 1895   1477819        35309           Blue Ribbon Sushi     Japanese
# 1897   1478056       120353           Blue Ribbon Sushi     Japanese
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0                 30.75         Weekend  Not given                   25.0
# 1                 12.08         Weekend  Not given                   25.0
# 6                  6.07         Weekend  Not given                   28.0
# 10                 5.92         Weekday  Not given                   34.0
# 14                12.13         Weekday  Not given                   23.0
# ...                 ...             ...        ...                    ...
# 1887               5.82         Weekend  Not given                   26.0
# 1891               5.82         Weekend  Not given                   22.0
# 1892              29.15         Weekend  Not given                   29.0
# 1895              25.22         Weekday  Not given                   31.0
# 1897              19.45         Weekend  Not given                   28.0
#
#      delivery_time
# 0               20
# 1              NaN
# 6               21
# 10              28
# 14              30
# ...            ...
# 1887            30
# 1891            28
# 1892            21
# 1895            24
# 1897            24
#
# [736 rows x 9 columns]

# %% [markdown]
# **Replacing all 'Not given' with the NULL**

# %%
df['rating']=df['rating'].replace('Not given',np.nan)

# %%
df['rating'].unique()
# Out:
# array([nan, '5', '3', '4'], dtype=object)

# %% [markdown]
# **Now there is not any wrong entry in the rating**

# %% [markdown]
# # Outliers

# %% [markdown]
# **First Check for Outliers**

# %%
for i in ['order_id','customer_id','cost_of_the_order','food_preparation_time']:
    plt.figure(figsize=(10,3))
    sns.boxplot(data=df,x=i)
    plt.show()

# %% [markdown]
# **Outliers in 'order_id', 'customer_id', 'cost_of_the_order', 'food_preparation_time'**

# %% [markdown]
# **Removing outliers**

# %%
def remove_outliers(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range,upper_range

# %% [markdown]
# **Since, ouliers is present in Cost of the order so REPLACING NULL values in Numerical Columns using Median**

# %%
median1=df['cost_of_the_order'].median()
median2=df['customer_id'].median()
median3=df['order_id'].median()
median4=df['food_preparation_time'].median()
# median5=df['rating'].median()
median6=df['delivery_time'].median()

df['cost_of_the_order'].replace(np.nan,median1,inplace=True)
df['customer_id'].replace(np.nan,median2,inplace=True)
df['order_id'].replace(np.nan,median3,inplace=True)
df['food_preparation_time'].replace(np.nan,median4,inplace=True)
# df['rating'].replace(np.nan,median5,inplace=True)
df['delivery_time'].replace(np.nan,median6,inplace=True)

# %% [markdown]
# **REPLACING NULL values in categorical columns using Mode**

# %%
mode1=df['restaurant_name'].mode().values[0]
mode2=df['cuisine_type'].mode().values[0]
mode3=df['day_of_the_week'].mode().values[0]


df['restaurant_name']=df['restaurant_name'].replace(np.nan,mode1)
df['cuisine_type']=df['cuisine_type'].replace(np.nan,mode2)
df['day_of_the_week']=df['day_of_the_week'].replace(np.nan,mode3)

# %%
ll,ul=remove_outliers(df['cost_of_the_order'])
df['cost_of_the_order']=np.where(df['cost_of_the_order']>ul,ul,df['cost_of_the_order'])
df['cost_of_the_order']=np.where(df['cost_of_the_order']<ll,ll,df['cost_of_the_order'])

# %% [markdown]
# **Boxplots after Outliers treatment**

# %%
for i in ['order_id','customer_id','cost_of_the_order','food_preparation_time']:
    plt.figure(figsize=(10,3))
    sns.boxplot(data=df,x=i)
    plt.show()

# %% [markdown]
# **Check for missing values in any column**

# %%
df.isnull().sum()
# Out:
# order_id                   0
# customer_id                0
# restaurant_name            0
# cuisine_type               0
# cost_of_the_order          0
# day_of_the_week            0
# rating                   736
# food_preparation_time      0
# delivery_time              0
# dtype: int64

# %% [markdown]
# # 1. Order Analysis

# %% [markdown]
# **a) What is the total number of orders in the dataset ?**

# %%
plt.figure(figsize=(2,3))
tno=sns.countplot(data=df,x=df['order_id'].value_counts())
for bars in tno.containers:
    tno.bar_label(bars)

# %% [markdown]
# **=>The Total number of orders are 1898**

# %% [markdown]
# **b) What is the average cost of an order?**

# %%
average_cost_of_order=df['cost_of_the_order'].mean()
average_cost_of_order
# Out:
# 16.50580874604847

# %% [markdown]
# **=>The Average Cost of Order is 16.50**

# %% [markdown]
# **c) How many unique customers have placed orders?**

# %%
unique_customers=df['customer_id'].nunique()
unique_customers
# Out:
# 1200

# %% [markdown]
# **=>The total Number of Unique customers have placed orders are 1200**

# %% [markdown]
# **d) Which restaurant has received the highest number of orders**

# %%
restaurant_order_counts = df['restaurant_name'].value_counts()
top_restaurant = restaurant_order_counts.idxmax()
top_order_count = restaurant_order_counts.max()
top_restaurant,top_order_count
# Out:
# ('Shake Shack', 219)

# %% [markdown]
# **=>Restaurant Shake Shack has received the highest number of orders : 219**

# %% [markdown]
# # 2. Customer Behavior

# %% [markdown]
# **a) What is the average rating given by customers?**

# %%
df['rating'].unique()
# Out:
# array([nan, '5', '3', '4'], dtype=object)

# %%
df['rating']=df['rating'].replace(np.nan,0)

# %%
df['rating']=df['rating'].astype('int')

# %%
df.dtypes
# Out:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                     int32
# food_preparation_time    float64
# delivery_time             object
# dtype: object

# %%
df['rating']=df['rating'].replace(0,np.nan)

# %%
df['rating'].mean(skipna=True)
# Out:
# 4.344234079173838

# %% [markdown]
# **=> The Average Rating given by Customers is 4.3**

# %% [markdown]
# **b) How does the rating vary between weekdays and weekends?**

# %%
plt.figure(figsize=(7,4))
bx = sns.countplot(data=df,x="rating",hue="day_of_the_week")
for bars in bx.containers:
    bx.bar_label(bars)

# %% [markdown]
# **c) Which cuisine type is ordered the most?**

# %%
cuisine_type=df['cuisine_type'].value_counts()
top_cuisine_type=cuisine_type.idxmax()
most_cuisine_type=cuisine_type.max()
top_cuisine_type,most_cuisine_type
# Out:
# ('American', 585)

# %% [markdown]
# **=> American cuisine type has ordered the most 585 times.**

# %% [markdown]
# **d) What is the distribution of orders across different days of the week?**

# %%
df['day_of_the_week'].unique()
# Out:
# array(['Weekend', 'Weekday'], dtype=object)

# %%
plt.figure(figsize=(6,5))
ax=sns.countplot(data=df,x='day_of_the_week')
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# **=> The distribution of orders across different days of the week ( Weekend and Weekday)**

# %% [markdown]
# # 3. Restaurant Performance

# %% [markdown]
# **a) What is the average food preparation time for each restaurant?**

# %%
df.groupby(['restaurant_name'],as_index=False)['food_preparation_time'].mean().sort_values(by='food_preparation_time',ascending=False)
# Out:
#             restaurant_name  food_preparation_time
# 39   Cipriani Le Specialita                   35.0
# 140            Sushi Choshi                   35.0
# 83        Kambi Ramen House                   35.0
# 85                    Klong                   35.0
# 148              Taro Sushi                   35.0
# ..                      ...                    ...
# 96             Market Table                   21.0
# 43                 DespaÌ±a                   20.5
# 3                 67 Burger                   20.0
# 58         Frank Restaurant                   20.0
# 68       Haru Gramercy Park                   20.0
#
# [178 rows x 2 columns]

# %% [markdown]
# **=> The average food preparation time for each restaurant**

# %% [markdown]
# **b) Which restaurant has the shortest average food preparation time?**

# %%
df.groupby(['restaurant_name'],as_index=False)['food_preparation_time'].mean().sort_values(by='food_preparation_time',ascending=True).head(10)
# Out:
#                 restaurant_name  food_preparation_time
# 68           Haru Gramercy Park                   20.0
# 3                     67 Burger                   20.0
# 58             Frank Restaurant                   20.0
# 43                     DespaÌ±a                   20.5
# 132             Sarabeth's West                   21.0
# 93                 Lucky Strike                   21.0
# 138  Song Thai Restaurant & Bar                   21.0
# 65          Hampton Chutney Co.                   21.0
# 128                Samurai Mama                   21.0
# 96                 Market Table                   21.0

# %% [markdown]
# **c) How does the average delivery time compare across different restaurants?**

# %%
df['delivery_time']=df['delivery_time'].astype('int')

# %%
df.groupby(['restaurant_name'],as_index=False)['delivery_time'].mean().sort_values(by='delivery_time',ascending=False)
# Out:
#         restaurant_name  delivery_time
# 132     Sarabeth's West           33.0
# 148          Taro Sushi           32.0
# 68   Haru Gramercy Park           32.0
# 58     Frank Restaurant           31.0
# 64               Haandi           30.5
# ..                  ...            ...
# 61     Galli Restaurant           16.0
# 152      The MasalaWala           15.0
# 110      Paul & Jimmy's           15.0
# 71               Hibino           15.0
# 60    Gaia Italian Cafe           15.0
#
# [178 rows x 2 columns]

# %% [markdown]
# **d) Is there a correlation between the cost of the order and the rating given?**

# %%
df[['cost_of_the_order','rating']].corr()
# Out:
#                    cost_of_the_order    rating
# cost_of_the_order           1.000000  0.028631
# rating                      0.028631  1.000000

# %% [markdown]
# **=> there is least correlation between the cost of order and the rating**

# %% [markdown]
# **HeatMap between the cost of order and the rating**

# %%
sns.heatmap(data=df[['cost_of_the_order','rating']].corr())
# Out:
# <Axes: >

# %% [markdown]
# # 4. Demand Patterns

# %% [markdown]
# **a) How does the demand for different cuisine types vary on weekdays versus weekends?**

# %%
df.groupby('day_of_the_week')['cuisine_type'].value_counts()
# Out:
# day_of_the_week  cuisine_type
# Weekday          American          169
#                  Japanese          135
#                  Italian            91
#                  Chinese            52
#                  Indian             24
#                  Mexican            24
#                  Middle Eastern     17
#                  Mediterranean      14
#                  Southern            6
#                  French              5
#                  Thai                4
#                  Vietnamese          3
#                  Korean              2
#                  Spanish             1
# Weekend          American          416
#                  Japanese          335
#                  Italian           207
#                  Chinese           163
#                  Mexican            52
#                  Indian             49
#                  Mediterranean      32
#                  Middle Eastern     32
#                  Thai               15
#                  French             13
#                  Korean             11
#                  Southern           11
#                  Spanish            11
#                  Vietnamese          4
# Name: cuisine_type, dtype: int64

# %% [markdown]
# **=>countplot between the cuisine type and the day of the week**

# %%
dc=sns.countplot(data=df,x=df['cuisine_type'],hue=df['day_of_the_week'])
plt.xticks(rotation=90)
for i in dc.containers:
    dc.bar_label(i)

# %% [markdown]
# **b) Which day of the week has the highest average order cost?**

# %%
df.groupby('day_of_the_week')['cost_of_the_order'].mean()
# Out:
# day_of_the_week
# Weekday    16.311188
# Weekend    16.584608
# Name: cost_of_the_order, dtype: float64

# %% [markdown]
# **Average cost of the order in day of the week**

# %% [markdown]
# **The barplot between the day of the week and the cost of the order**

# %%
plt.figure(figsize=(2,4))
sns.barplot(data=df,x=df['day_of_the_week'],y=df['cost_of_the_order'])
# Out:
# <Axes: xlabel='day_of_the_week', ylabel='cost_of_the_order'>

# %% [markdown]
# **c) What is the most common day for orders to be placed?**

# %%
df1=df.groupby('day_of_the_week')['order_id'].count()
df1
# Out:
# day_of_the_week
# Weekday     547
# Weekend    1351
# Name: order_id, dtype: int64

# %% [markdown]
# **=> The most common day for orders to be placed is Weekend**

# %% [markdown]
# **The Barplot between day of the week and the order Id**

# %%
plt.figure(figsize=(2,4))
cdo=sns.barplot(data=df,x=df1.index,y=df1.values)
for i in cdo.containers:
    cdo.bar_label(i)

# %% [markdown]
# **d) How does the average rating vary by cuisine type?**

# %%
df.groupby('cuisine_type')['rating'].mean()
# Out:
# cuisine_type
# American          4.300813
# Chinese           4.338346
# French            4.300000
# Indian            4.540000
# Italian           4.360465
# Japanese          4.373626
# Korean            4.111111
# Mediterranean     4.218750
# Mexican           4.404255
# Middle Eastern    4.235294
# Southern          4.307692
# Spanish           4.833333
# Thai              4.666667
# Vietnamese        4.000000
# Name: rating, dtype: float64

# %% [markdown]
# **=> Barplot between the cuisine Type and teh rating**

# %%
plt.figure(figsize=(15,5))
cr=sns.barplot(data=df,x=df['cuisine_type'],y=df['rating'])
plt.xticks(rotation=90)
for i in cr.containers:
    cr.bar_label(i)
# Out:
# C:\Users\himanshu\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %% [markdown]
# # 5. Operational Efficiency

# %% [markdown]
# **a) What is the average delivery time for all orders?**

# %%
df['delivery_time'].mean()
# Out:
# 24.163329820864067

# %% [markdown]
# **=> The Average Delivery time for all the orders is 24.16 min**

# %% [markdown]
# **b) Which restaurant has the longest average delivery time?**

# %%
longest_avg_dt=df.groupby('restaurant_name')['delivery_time'].mean()
longest_avg_dt.idxmax(),longest_avg_dt.max()
# Out:
# ("Sarabeth's West", 33.0)

# %% [markdown]
# **=> The Sarabeth restaurant has the longest average Delivery time of 33 min**

# %% [markdown]
# **c) Is there a relationship between food preparation time and delivery time?**

# %%
df[['food_preparation_time','delivery_time']].corr()
# Out:
#                        food_preparation_time  delivery_time
# food_preparation_time               1.000000       0.011234
# delivery_time                       0.011234       1.000000

# %% [markdown]
# **=> The Correlation between the food preparation time and delivery time os minimal**

# %% [markdown]
# **=> Heatmap between the food preparation time and delivery time**

# %%
sns.heatmap(data=df[['food_preparation_time','delivery_time']].corr())
# Out:
# <Axes: >

# %% [markdown]
# **d) How does the delivery time impact customer ratings?**

# %%
df[['delivery_time','rating']].corr()
# Out:
#                delivery_time    rating
# delivery_time       1.000000 -0.010121
# rating             -0.010121  1.000000

# %% [markdown]
# **=> The Delivery and Rating has the minal correlation in between**

# %% [markdown]
# **Heatmap in between the The delivery and rating**

# %%
sns.heatmap(data=df[['delivery_time','rating']].corr())
# Out:
# <Axes: >

# %% [markdown]
# # 6. Customer Insights

# %% [markdown]
# **a) What is the repeat order rate (number of customers who have placed more than one order)?**

# %%
df2=df[df['customer_id'].duplicated()]
df3=df2['customer_id'].value_counts()
df3[df3.values>1].head(10)
# Out:
# 52832     12
# 47440      9
# 83287      8
# 250494     7
# 259341     6
# 65009      6
# 276192     6
# 82041      6
# 60052      5
# 97991      5
# Name: customer_id, dtype: int64

# %% [markdown]
# **b) What percentage of orders receive a rating of 4 or higher?**

# %%
(df[df['rating'] >= 4].shape[0] / df.shape[0]) * 100
# Out:
# 51.31717597471022

# %% [markdown]
# **=> The percentage of orders receive the rating of 4 or higher is 51.31%**

# %% [markdown]
# **Piechart for the rating of 4 and higher**

# %%
rating_counts = [df[df['rating'] >= 4].shape[0], df[df['rating'] < 4].shape[0]]
rating_labels = ['Rating 4 or Higher', 'Rating Below 4']
plt.figure(figsize=(4, 4))
plt.pie(rating_counts, labels=rating_labels, autopct='%1.1f%%', colors=['#4CAF50', '#FF5722'], startangle=140)
plt.title('Percentage of Orders with Rating 4 or Higher')
plt.show()
